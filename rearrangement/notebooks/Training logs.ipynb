# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.simplefilter('ignore')
from rearrangement.utils.logs import plot_fields as pf
from pathlib import Path
import matplotlib.pyplot as plt
log_dir = Path('../../data/models/')
def plot_fields(*args, **kwargs): return pf(*args, log_dir=log_dir, **kwargs)

# %%
ids = [
    'state-prediction-71538',
]

# %%
plt.figure(figsize=(20,20))
plot_fields(ids, ['train_loss', 'val_loss'], subplot=231, title='total loss')
plot_fields(ids, ['train_loss_field', 'val_loss_field'], subplot=232, title='xy field loss')
plot_fields(ids, ['train_loss_mask','val_loss_mask'], subplot=233, title='mask loss')
plot_fields(ids, ['train_loss_class','val_loss_class'], subplot=234, title='class loss')
plot_fields(ids, ['train_loss_depth','val_loss_depth'], subplot=235, title='depth loss')
